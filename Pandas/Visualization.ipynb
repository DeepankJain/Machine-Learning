# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/DeepankJain/Machine-Learning/blob/master/Pandas/Visualization.ipynb)

# %%
import pandas as pd
import collections
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df = pd.read_csv(url, sep = '\t')

# %%
#create a histogram of top 5 items bought?
x = df['item_name']
letter_counts = collections.Counter(x)
df1 = pd.DataFrame.from_dict(letter_counts, orient = 'index')
df1 = df1[0].sort_values(ascending = True)[45:50]
df1.plot(kind  = 'bar')
plt.xlabel("Items")
plt.ylabel("Price")
plt.title("Most ordered items")
plt.show()

# %%
plt.close()
